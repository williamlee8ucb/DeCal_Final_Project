# %%
import pandas as pd

# %%
pd.read_csv("galaxydatabase.csv", encoding = "ISO-8859-1")
# Out:
#         Name    Type   Mag  Dist. / kpc Constellation  R.A.  Rahours  \
# 0    NGC 628  Galaxy   9.3         10.7        Pisces   136        1
# 1    NGC 477  Galaxy  13.9     101000.0     Andromeda   121        1
# 2    NGC 364  Galaxy  14.2     101900.0         Cetus   104        1
# 3     NGC 64  Galaxy  14.1     102000.0         Cetus    17        0
# 4     NGC 90  Galaxy  13.8     102350.0     Andromeda    21        0
# ..       ...     ...   ...          ...           ...   ...      ...
# 389  NGC 934  Galaxy  13.4      96300.0         Cetus   227        2
# 390  NGC 409  Galaxy  14.1      96400.0      Sculptor   109        1
# 391    NGC 2  Galaxy  16.2      96800.0       Pegasus     7        0
# 392  NGC 223  Galaxy  14.3      97700.0         Cetus    42        0
# 393  NGC 219  Galaxy  15.2      98300.0         Cetus    42        0
#
#      Raminutes  Radeg    Decl.  Decdeg  Decmin    DeclDeg     RadRa    RadDec  \
# ...
